# %%
from alpha_vantage.timeseries import TimeSeries
import os
import pandas as pd
ts=TimeSeries(key="", output_format="pandas")

# %%
data, meta_data = ts.get_daily("ENPH", outputsize="full")

# %%
data.tail()
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# date
# 2019-11-04    18.92    19.13   17.18     17.95  11735600.0
# 2019-11-05    17.55    18.75   17.30     18.59   5514500.0
# 2019-11-06    18.54    19.18   17.87     18.20   4767500.0
# 2019-11-07    18.32    18.77   17.71     18.00   3690500.0
# 2019-11-08    17.96    18.49   17.87     18.44   2725909.0

# %%
data.columns=["open","high","low","close","volume"]

# %%
# data.to_csv("enph.csv")

# %%
data.close.plot()

# %%
# TODO: scrape EIA data: https://www.eia.gov/electricity/monthly/epm_table_grapher.php?t=epmt_1_17_a
